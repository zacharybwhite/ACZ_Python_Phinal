# %%
import tweepy

# %%
consumer_key = "HBxg78O70LqOptDY2BeAMeDls"
consumer_secret = "AHtki992KQfYynoL2qsipDJ6k0EMDr15KTG4q0IZG2mWMOmyaA"
access_token = "1251920853878611970-0bowmPpv96LrAmD2GGpvyAXQtI9UC7"
access_token_secret = "qlKF6rTuzMNJIBnqnp4kSx6H1y9h2KwowqaiMwGeDBvR1"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
import pandas as pd
twitter_frame = pd.read_csv("covid_congress.csv")

twitter_frame
# Out:
#     chamber state  district       party    Twitter Handle   lastName  \
# 0       rep    LA       5.0  Republican       @RepAbraham    Abraham
# 1       rep    NC      12.0    Democrat         @RepAdams      Adams
# 2       rep    AL       4.0  Republican  @Robert_Aderholt   Aderholt
# 3       rep    CA      31.0    Democrat   @RepPeteAguilar    Aguilar
# 4       sen    TN       NaN  Republican     @SenAlexander  Alexander
# ..      ...   ...       ...         ...               ...        ...
# 534     rep    KY       3.0    Democrat   @RepJohnYarmuth    Yarmuth
# 535     rep    FL       3.0  Republican       @RepTedYoho       Yoho
# 536     rep    AK       0.0  Republican      @repdonyoung      Young
# 537     sen    IN       NaN  Republican     @SenToddYoung      Young
# 538     rep    NY       1.0  Republican     @RepLeeZeldin     Zeldin
#
#     firstName    officialFullName startTerm   endTerm  ...  \
# 0       Ralph   Ralph Lee Abraham  1/3/2019  1/3/2021  ...
# 1        Alma       Alma S. Adams  1/3/2019  1/3/2021  ...
# 2      Robert  Robert B. Aderholt  1/3/2019  1/3/2021  ...
# 3        Pete        Pete Aguilar  1/3/2019  1/3/2021  ...
# 4       Lamar     Lamar Alexander  1/6/2015  1/3/2021  ...
# ..        ...                 ...       ...       ...  ...
# 534      John     John A. Yarmuth  1/3/2019  1/3/2021  ...
# 535       Ted         Ted S. Yoho  1/3/2019  1/3/2021  ...
# 536       Don           Don Young  1/3/2019  1/3/2021  ...
# 537      Todd          Todd Young  1/3/2017  1/3/2023  ...
# 538       Lee       Lee M. Zeldin  1/3/2019  1/3/2021  ...
#
#     asianPacificIslanderCitizenVotingAgePopulation  \
# 0                                           2345.0
# 1                                          16510.0
# 2                                           2330.0
# 3                                          32865.0
# 4                                          50235.0
# ..                                             ...
# 534                                         7670.0
# 535                                        13620.0
# 536                                        26625.0
# 537                                        49045.0
# 538                                        14840.0
#
#      nativeCitizenVotingAgePopulation otherCitizenVotingAgePopulation  \
# 0                              2295.0                          4010.0
# 1                              1495.0                         10540.0
# 2                              3775.0                          6395.0
# 3                              1320.0                          9515.0
# 4                             12065.0                         57765.0
# ..                                ...                             ...
# 534                             765.0                          8220.0
# 535                            1475.0                          8050.0
# 536                           68570.0                         29325.0
# 537                           10345.0                         53650.0
# 538                             925.0                          4000.0
#
#     censusTotalPopulation censusWhitePopulation censusBlackPopulation  \
# 0                755317.0              458328.0              265012.0
# 1                733894.0              312781.0              281939.0
# 2                681487.0              578453.0               46163.0
# 3                704230.0              209488.0               76800.0
# 4               6346105.0             4800782.0             1049391.0
# ..                    ...                   ...                   ...
# 534              723136.0              506794.0              151669.0
# 535              693992.0              487768.0              111555.0
# 536              708570.0              454831.0               21862.0
# 537             6483802.0             5286453.0              582140.0
# 538              717177.0              558724.0               32109.0
#
#     censusLatinoPopulation  censusAsianPacificIslanderPopulation  \
# 0                  15313.0                                5074.0
# 1                 102704.0                               34323.0
# 2                  38837.0                                3200.0
# 3                 347395.0                               51105.0
# 4                 290059.0                               93078.0
# ..                     ...                                   ...
# 534                32131.0                               15841.0
# 535                56511.0                               21708.0
# 536                39038.0                               44357.0
# 537               389707.0                              103297.0
# 538                89960.0                               24029.0
#
#      censusNavtiveAmericanPopulation  censusOtherPopulation
# 0                             3155.0                 8435.0
# 1                             3734.0                54218.0
# 2                             5218.0                 9616.0
# 3                             2154.0                17288.0
# 4                            16302.0                96493.0
# ..                               ...                    ...
# 534                           1454.0                 1232.0
# 535                           2126.0                14324.0
# 536                         102124.0                46358.0
# 537                          14165.0               108040.0
# 538                           1735.0                10620.0
#
# [539 rows x 73 columns]

# %%
handle_list = []

for handle in twitter_frame["Twitter Handle"]:
    handle_list.append(handle)
    
handle_list
# Out:
# ['@RepAbraham',
#  '@RepAdams',
#  '@Robert_Aderholt',
#  '@RepPeteAguilar',
#  '@SenAlexander',
#  '@RepRickAllen',
#  '@RepColinAllred',
#  '@justinamash',
#  '@RepAmata',
#  '@MarkAmodeiNV2',
#  '@RepArmstrongND',
#  '@RepArrington',
#  '@RepCindyAxne',
#  '@RepBrianBabin',
#  '@RepDonBacon',
#  '@RepJimBaird',
#  '@RepBalderson',
#  '@SenatorBaldwin',
#  '@RepJimBanks',
#  '@RepAndyBarr',
#  '@RepBarragan',
#  '@SenJohnBarrasso',
#  '@RepKarenBass',
#  '@RepBeatty',
#  '@SenatorBennet',
#  '@RepBera',
#  '@RepJackBergman',
#  '@RepDonBeyer',
#  '@RepAndyBiggsAZ',
#  '@RepGusBilirakis',
#  '@SanfordBishop',
#  '@RepRobBishop',
#  '@MarshaBlackburn',
#  '@repblumenauer',
#  '@SenBlumenthal',
#  '@RoyBlunt',
#  '@RepLBR',
#  '@RepBonamici',
#  '@SenBooker',
#  '@JohnBoozman',
#  '@RepBost',
#  '@CongBoyle',
#  '@RepKevinBrady',
#  '@SenatorBraun',
#  '@RepBrindisi',
#  '@RepMoBrooks',
#  '@SusanWBrooks',
#  '@RepAnthonyBrown',
#  '@SenSherrodBrown',
#  '@RepBrownley',
#  '@VernBuchanan',
#  '@RepKenBuck',
#  '@RepLarryBucshon',
#  '@RepTedBudd',
#  '@RepTimBurchett',
#  '@michaelcburgess',
#  '@SenatorBurr',
#  '@RepCheri',
#  '@GKButterfield',
#  '@RepByrne',
#  '@RepCardenas',
#  '@KenCalvert',
#  '@SenatorCantwell',
#  '@SenCapito',
#  '@RepCarbajal',
#  '@SenatorCardin',
#  '@SenatorCarper',
#  '@RepAndreCarson',
#  '@RepBuddyCarter',
#  '@JudgeCarter',
#  '@RepCartwright',
#  '@RepEdCase',
#  '@SenBobCasey',
#  '@SenBillCassidy',
#  '@RepCasten',
#  '@USRepKCastor',
#  '@JoaquinCastrotx',
#  '@RepSteveChabot',
#  '@RepLizCheney',
#  '@RepJudyChu',
#  '@davidcicilline',
#  '@RepGilCisneros',
#  '@RepKClark',
#  '@RepYvetteClarke',
#  '@LacyClayMO1',
#  '@repcleaver',
#  '@RepBenCline',
#  '@RepCloudTX',
#  '@WhipClyburn',
#  '@RepCohen',
#  '@TomColeOK04',
#  '@RepDougCollins',
#  '@SenatorCollins',
#  '@RepChrisCollins',
#  nan,
#  '@ConawayTX11',
#  '@GerryConnolly',
#  '@RepPaulCook',
#  '@ChrisCoons',
#  '@repjimcooper',
#  '@JohnCornyn',
#  '@RepLouCorrea',
#  '@SenCortezMasto',
#  '@RepJimCosta',
#  '@SenTomCotton',
#  '@RepJoeCourtney',
#  '@RepTjCox',
#  '@RepAngieCraig',
#  '@SenKevinCramer',
#  '@MikeCrapo',
#  '@RepRickCrawford',
#  '@RepDanCrenshaw',
#  '@RepCharlieCrist',
#  '@RepJasonCrow',
#  '@SenTedCruz',
#  '@RepCuellar',
#  '@RepCummings',
#  '@RepCunningham',
#  '@RepJohnCurtis',
#  '@SteveDaines',
#  '@RepDavids',
#  '@WarrenDavidson',
#  '@RepSusanDavis',
#  '@RepDannyDavis',
#  '@RodneyDavis',
#  '@RepDean',
#  '@RepPeterDeFazio',
#  '@RepDianaDeGette',
#  '@rosadelauro',
#  '@RepDelBene',
#  '@repdelgado',
#  '@RepValDemings',
#  '@RepDeSaulnier',
#  '@DesJarlaisTN04',
#  '@RepTedDeutch',
#  '@MarioDB',
#  '@RepDebDingell',
#  '@RepLloydDoggett',
#  '@USRepMikeDoyle',
#  '@SenDuckworth',
#  '@RepSeanDuffy',
#  '@RepJeffDuncan',
#  '@DrNealDunnFL2',
#  '@SenatorDurbin',
#  '@RepTomEmmer',
#  '@RepEliotEngel',
#  '@SenatorEnzi',
#  '@SenJoniErnst',
#  '@RepEscobar',
#  '@RepAnnaEshoo',
#  '@RepEspaillat',
#  '@RepRonEstes',
#  '@RepDwightEvans',
#  '@SenFeinstein',
#  '@RepDrewFerguson',
#  '@RepFinkenauer',
#  '@SenatorFischer',
#  '@RepBrianFitz',
#  '@RepChuck',
#  '@RepFletcher',
#  '@RepBillFlores',
#  '@JeffFortenberry',
#  '@RepBillFoster',
#  '@virginiafoxx',
#  '@RepLoisFrankel',
#  '@RepMarciaFudge',
#  '@RepRussFulcher',
#  '@TulsiPress',
#  '@RepMattGaetz',
#  '@RepGallagher',
#  '@RepRubenGallego',
#  '@RepGaramendi',
#  '@RepChuyGarcia',
#  '@RepSylviaGarcia',
#  '@SenCoryGardner',
#  nan,
#  '@RepBobGibbs',
#  '@gillibrandny',
#  '@replouiegohmert',
#  '@RepGolden',
#  '@RepJimmyGomez',
#  '@RepJenniffer',
#  '@RepAGonzalez',
#  '@RepGonzalez',
#  '@RepLanceGooden',
#  '@RepGosar',
#  '@RepJoshG',
#  '@LindseyGrahamSC',
#  '@RepKayGranger',
#  '@ChuckGrassley',
#  '@RepTomGraves',
#  '@RepGarretGraves',
#  '@RepSamGraves',
#  '@RepMarkGreen',
#  '@RepAlGreen',
#  '@RepMGriffith',
#  '@RepRaulGrijalva',
#  '@RepGrothman',
#  '@RepMichaelGuest',
#  '@RepGuthrie',
#  '@RepDebHaaland',
#  '@RepHagedorn',
#  '@RepJoshHarder',
#  '@SenKamalaHarris',
#  '@RepAndyHarrisMD',
#  '@RepHartzler',
#  '@SenatorHassan',
#  '@RepHastingsFL',
#  '@SenHawleyPress',
#  '@RepJahanaHayes',
#  '@RepDennyHeck',
#  '@MartinHeinrich',
#  '@repkevinhern',
#  '@HerreraBeutler',
#  '@CongressmanHice',
#  '@RepClayHiggins',
#  '@RepBrianHiggins',
#  '@RepFrenchHill',
#  '@RepKatieHill',
#  '@jahimes',
#  '@maziehirono',
#  '@SenJohnHoeven',
#  '@RepHolding',
#  '@RepTrey',
#  '@RepKendraHorn',
#  '@RepHorsford',
#  '@RepHoulahan',
#  '@LeaderHoyer',
#  '@RepRichHudson',
#  '@RepHuffman',
#  '@RepHuizenga',
#  '@Rep_Hunter',
#  '@HurdOnTheHill',
#  '@SenHydeSmith',
#  '@JimInhofe',
#  '@SenatorIsakson',
#  '@JacksonLeeTX18',
#  '@RepJayapal',
#  '@RepJeffries',
#  '@RepHankJohnson',
#  '@RepMikeJohnson',
#  '@RepBillJohnson',
#  '@RepDustyJohnson',
#  '@RepEBJ',
#  '@SenRonJohnson',
#  '@SenDougJones',
#  '@RepWalterJones',
#  '@Jim_Jordan',
#  '@RepDaveJoyce',
#  '@RepJohnJoyce',
#  nan,
#  '@RepMarcyKaptur',
#  '@RepJohnKatko',
#  '@USRepKeating',
#  '@RepRobinKelly',
#  '@RepTrentKelly',
#  '@MikeKellyPA',
#  '@SenJohnKennedy',
#  '@RepJoeKennedy',
#  '@RepRoKhanna',
#  '@RepDanKildee',
#  '@RepDerekKilmer',
#  '@RepAndyKimNJ',
#  '@RepRonKind',
#  nan,
#  '@SenAngusKing',
#  '@RepPeteKing',
#  '@RepKinzinger',
#  '@RepKirkpatrick',
#  '@SenAmyKlobuchar',
#  '@CongressmanRaja',
#  '@RepAnnieKuster',
#  '@RepDavidKustoff',
#  '@RepLaHood',
#  '@RepLaMalfa',
#  '@RepConorLamb',
#  '@RepDLamborn',
#  '@JimLangevin',
#  '@SenatorLankford',
#  '@RepRickLarsen',
#  '@RepJohnLarson',
#  '@boblatta',
#  '@RepLawrence',
#  '@RepAlLawsonJr',
#  '@SenatorLeahy',
#  '@RepBarbaraLee',
#  '@RepSusieLee',
#  '@SenMikeLee',
#  '@RepDLesko',
#  '@RepMikeLevin',
#  '@RepAndyLevin',
#  '@repjohnlewis',
#  '@RepTedLieu',
#  '@RepLipinski',
#  '@daveloebsack',
#  '@RepZoeLofgren',
#  '@USRepLong',
#  '@RepLoudermilk',
#  '@RepLowenthal',
#  '@NitaLowey',
#  '@RepFrankLucas',
#  '@RepBlaine',
#  '@repbenraylujan',
#  '@RepElaineLuria',
#  '@RepStephenLynch',
#  '@RepMalinowski',
#  '@RepMaloney',
#  '@RepSeanMaloney',
#  '@Sen_JoeManchin',
#  '@RepKenMarchant',
#  '@SenMarkey',
#  nan,
#  '@RepThomasMassie',
#  '@RepBrianMast',
#  '@DorisMatsui',
#  '@RepBenMcAdams',
#  '@RepLucyMcBath',
#  '@GOPLeader',
#  '@RepMcCaul',
#  '@RepMcClintock',
#  '@BettyMcCollum04',
#  '@SenateMajLdr',
#  '@RepMcEachin',
#  '@RepMcGovern',
#  '@PatrickMcHenry',
#  '@RepMcKinley',
#  '@cathymcmorris',
#  '@RepMcNerney',
#  '@SenMcSallyAZ',
#  '@RepMarkMeadows',
#  '@RepGregoryMeeks',
#  '@SenatorMenendez',
#  '@RepGraceMeng',
#  '@SenJeffMerkley',
#  '@RepMeuser',
#  '@RepCarolMiller',
#  '@RepPaulMitchell',
#  '@RepMoolenaar',
#  '@RepAlexMooney',
#  '@RepGwenMoore',
#  '@JerryMoran',
#  '@RepJoeMorelle',
#  '@teammoulton',
#  '@RepDMP',
#  '@RepMullin',
#  '@lisamurkowski',
#  '@SenMurphyOffice',
#  '@RepStephMurphy',
#  '@PattyMurray',
#  '@RepJerryNadler',
#  '@gracenapolitano',
#  '@RepRichardNeal',
#  '@RepJoeNeguse',
#  '@RepNewhouse',
#  '@DonaldNorcross',
#  '@RepRalphNorman',
#  '@EleanorNorton',
#  '@RepDevinNunes',
#  '@RepOHalleran',
#  '@RepAOC',
#  '@RepPeteOlson',
#  '@Ilhan',
#  '@CongPalazzo',
#  '@FrankPallone',
#  '@USRepGaryPalmer',
#  '@RepJimmyPanetta',
#  '@RepChrisPappas',
#  '@BillPascrell',
#  '@RandPaul',
#  '@RepDonaldPayne',
#  '@SpeakerPelosi',
#  '@RepGregPence',
#  '@sendavidperdue',
#  '@RepPerlmutter',
#  '@RepScottPerry',
#  '@RepScottPeters',
#  '@SenGaryPeters',
#  nan,
#  '@RepDeanPhillips',
#  '@chelliepingree',
#  '@StaceyPlaskett',
#  '@repmarkpocan',
#  '@RepKatiePorter',
#  '@senrobportman',
#  '@congbillposey',
#  '@RepPressley',
#  '@RepDavidEPrice',
#  '@RepMikeQuigley',
#  '@RepRaskin',
#  '@RepRatcliffe',
#  '@RepTomReed',
#  '@SenJackReed',
#  '@GReschenthaler',
#  '@RepKathleenRice',
#  '@RepTomRice',
#  '@RepRichmond',
#  '@RepRiggleman',
#  '@SenatorRisch',
#  '@SenPatRoberts',
#  '@RepMarthaRoby',
#  '@DrPhilRoe',
#  '@RepMikeRogersAL',
#  '@RepHalRogers',
#  '@SenatorRomney',
#  '@RepRooney',
#  '@RepMaxRose',
#  '@RepJohnRose',
#  '@SenJackyRosen',
#  '@RepHarley',
#  '@SenatorRounds',
#  '@RepDavidRouzer',
#  '@RepChipRoy',
#  '@RepRoybalAllard',
#  '@SenRubioPress',
#  '@CongressmanRuiz',
#  '@Call_Me_Dutch',
#  '@RepBobbyRush',
#  '@RepRutherfordFL',
#  '@RepTimRyan',
#  '@RepLindaSanchez',
#  '@Kilili_Sablan',
#  '@GuamCongressman',
#  '@SenSanders',
#  '@RepSarbanes',
#  '@SenSasse',
#  '@SteveScalise',
#  '@RepMGS',
#  '@janschakowsky',
#  '@SenBrianSchatz',
#  '@RepAdamSchiff',
#  '@RepSchneider',
#  '@RepSchrader',
#  '@RepKimSchrier',
#  '@SenSchumer',
#  '@RepDavid',
#  '@SenRickScott',
#  '@AustinScottGA08',
#  '@repdavidscott',
#  '@SenatorTimScott',
#  '@BobbyScott',
#  '@JimPressOffice',
#  '@RepJoseSerrano',
#  '@RepTerriSewell',
#  '@SenatorShaheen',
#  '@RepShalala',
#  '@SenShelby',
#  '@BradSherman',
#  '@RepSherrill',
#  '@RepShimkus',
#  '@CongMikeSimpson',
#  '@SenatorSinema',
#  '@RepSires',
#  '@RepSlotkin',
#  '@SenTinaSmith',
#  '@RepJasonSmith',
#  '@RepAdrianSmith',
#  '@RepChrisSmith',
#  '@RepAdamSmith',
#  '@RepSmucker',
#  '@RepDarrenSoto',
#  '@RepSpanberger',
#  '@RepRossSpano',
#  '@RepSpeier',
#  '@SenStabenow',
#  '@RepGregStanton',
#  '@RepPeteStauber',
#  '@RepStefanik',
#  '@RepBryanSteil',
#  '@RepGregSteube',
#  '@RepHaleyStevens',
#  '@RepChrisStewart',
#  '@RepSteveStivers',
#  '@SenDanSullivan',
#  '@RepTomSuozzi',
#  '@RepSwalwell',
#  '@RepMarkTakano',
#  '@RepVanTaylor',
#  '@SenatorTester',
#  '@RepThompson',
#  '@BennieGThompson',
#  '@CongressmanGT',
#  '@MacTXPress',
#  '@SenJohnThune',
#  '@SenThomTillis',
#  '@reptimmons',
#  '@RepTipton',
#  '@repdinatitus',
#  '@RepRashida',
#  '@RepPaulTonko',
#  '@SenToomey',
#  '@NormaJTorres',
#  '@RepTorresSmall',
#  '@RepLoriTrahan',
#  '@RepDavidTrone',
#  '@RepMikeTurner',
#  '@SenatorTomUdall',
#  '@RepUnderwood',
#  '@RepFredUpton',
#  '@CongressmanJVD',
#  '@ChrisVanHollen',
#  '@RepJuanVargas',
#  '@RepVeasey',
#  '@NydiaVelazquez',
#  '@RepFilemonVela',
#  '@RepVisclosky',
#  '@RepAnnWagner',
#  '@RepWalberg',
#  '@repgregwalden',
#  '@RepMarkWalker',
#  '@RepWalorski',
#  '@RepMichaelWaltz',
#  '@MarkWarner',
#  '@SenWarren',
#  '@DWStweets',
#  '@RepMaxineWaters',
#  nan,
#  '@RepBonnie',
#  '@TXRandy14',
#  '@RepWebster',
#  '@PeterWelch',
#  '@RepBradWenstrup',
#  '@RepWesterman',
#  '@RepWexton',
#  '@SenWhitehouse',
#  '@SenatorWicker',
#  '@RepSusanWild',
#  '@RepRWilliams',
#  '@RepWilson',
#  '@RepJoeWilson',
#  '@RobWittman',
#  '@rep_stevewomack',
#  '@RepRobWoodall',
#  '@RepRonWright',
#  '@RonWyden',
#  '@RepJohnYarmuth',
#  '@RepTedYoho',
#  '@repdonyoung',
#  '@SenToddYoung',
#  '@RepLeeZeldin']

# %%
#handle_list.remove("@RepChrisCollins")
handle_list.remove("@RepSeanDuffy")

# %%
allhandle_dict = {}

for handle in handle_list:
    tweets = []
    username = handle
    count = 100

    for tweet in api.user_timeline(id=username, count=count):
        tweets.append((tweet.created_at,tweet.id,tweet.text))
    
    allhandle_dict[handle] = tweets
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-29-0a4be0e8ff08> in <module>
#       6     count = 100
#       7
# ----> 8     for tweet in api.user_timeline(id=username, count=count):
#       9         tweets.append((tweet.created_at,tweet.id,tweet.text))
#      10
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: [{'code': 89, 'message': 'Invalid or expired token.'}]

# %%
allhandle_dict["@RepAndyBarr"]

# %%
china_tweets_dict = {}
china_tweets = []

for handle in handle_list:
    for tweet in allhandle_dict[handle]:
        if tweet[2].find("China") >= 0:
            china_tweets.append(tweet[2])
            #print(tweet[2])
    china_tweets_dict[handle] = china_tweets

# %%
# .groupby(handle) or .groupby(state)
# DataFrame instead of a dictionary ~ Pandas
# Normalize somehow (emotions per Tweet?) because more Tweets might skew the data.
# COVID baseline
# Split at periods to analyze sentences that contain China instead of whole Tweet?
# Average the Tweet sentiment for each legislator (that is, across their Tweets)
# 1) Reorganize all the Tweets into a Pandas DataFrame
# 2) Run sentiment anal-ysis on every single Tweet in the DataFrame.
# 3) Aggregate the sentiment by legislator/state. .groupby() After groupby(), analyze by sum or by average.
# 4) Make a histogram of sentiment.
# 5) Sort the histogram by positive/negative emotions, sort it, label by party (red or blue).
# 6) Can run a correlation to see if red or blue correlates to different sentiments on different topics.
# 7) Subtract COVID sentiment from China sentiment - for "net China"? China minus COVID
